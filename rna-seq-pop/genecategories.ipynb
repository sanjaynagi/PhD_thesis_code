# %%
import pandas as pd

# %%
import numpy as np

# %%
res = pd.read_csv("../../results/genediff/BusiaParental_BusiaSelected.csv")

# %%
sig = res.query("padj < 0.05")

# %%
sig[sig.GeneDescription.str.contains('ABC', na=False)].sort_values(by='FC')
# Out:
#           GeneID      baseMean  log2FoldChange     lfcSE      stat  \
# 758   AGAP011518   1013.957505       -1.889117  0.281243 -6.717024
# 1350  AGAP000506    273.876918       -0.849464  0.155820 -5.451563
# 1006  AGAP002050    565.309435       -0.793098  0.130101 -6.096000
# 1584  AGAP002051    434.166777       -0.755810  0.149026 -5.071683
# 2644  AGAP009799   2065.382476       -0.619245  0.156108 -3.966768
# 2620  AGAP009471    373.420929       -0.599729  0.150560 -3.983319
# 3840  AGAP001775   5208.115982       -0.582487  0.183162 -3.180166
# 4273  AGAP002060    347.767024       -0.559784  0.189983 -2.946499
# 2261  AGAP010416   1552.193461       -0.465082  0.108407 -4.290142
# 4968  AGAP009467    188.803752       -0.458717  0.177141 -2.589558
# 2867  AGAP000300   9161.187397       -0.412879  0.108941 -3.789943
# 4834  AGAP007504    787.740790       -0.392398  0.148188 -2.647969
# 3807  AGAP002693  15431.792651        0.188555  0.059007  3.195465
# ...

# %%
sig[sig.GeneDescription.str.contains('carboxylesterase', na=False)].sort_values(by='FC')
# Out:
#           GeneID     baseMean  log2FoldChange     lfcSE      stat  \
# 1181  AGAP006723   415.634506       -2.595250  0.449461 -5.774143
# 376   AGAP011916   818.068534       -1.454685  0.179491 -8.104515
# 506   AGAP002090  1333.056087       -1.292059  0.171026 -7.554761
# 707   AGAP003115   821.072263       -1.244480  0.181039 -6.874090
# 554   AGAP003568  1186.868388       -1.242665  0.168891 -7.357783
# 1583  AGAP002391    92.094289       -1.060550  0.209096 -5.072081
# 1889  AGAP006726   501.654175       -0.730168  0.155833 -4.685583
# 3873  AGAP005837   382.987984       -0.724789  0.229505 -3.158048
# 1396  AGAP011575   136.193335       -0.697999  0.129913 -5.372813
# 5216  AGAP011365    65.077485       -0.674093  0.271655 -2.481428
# 2193  AGAP005758   195.148820       -0.633190  0.145315 -4.357360
# 3491  AGAP001101   660.325325       -0.439094  0.130413 -3.366957
# 5629  AGAP006724   597.276530       -0.424946  0.184789 -2.299628
# ...

# %%
sig[sig.GeneDescription.str.contains('cytochrome P450', na=False)].sort_values(by='FC')
# Out:
#           GeneID      baseMean  log2FoldChange     lfcSE       stat  \
# 2189  AGAP008682     10.396945       -2.152783  0.493727  -4.360273
# 2645  AGAP013241     17.896190       -1.977109  0.498523  -3.965937
# 756   AGAP009374    198.733311       -1.868068  0.277961  -6.720619
# 4512  AGAP002866     30.720867       -1.686565  0.598600  -2.817517
# 459   AGAP005660     87.217572       -1.686091  0.217371  -7.756750
# 845   AGAP009363    301.554785       -1.641628  0.253722  -6.470180
# 2894  AGAP002555     48.487803       -1.563604  0.415076  -3.767027
# 105   AGAP005774    221.215882       -1.551491  0.151367 -10.249880
# 515   AGAP005658    180.435253       -1.394613  0.185363  -7.523700
# 4166  AGAP002870     17.106173       -1.372844  0.457293  -3.002108
# 5448  AGAP010966     10.819786       -1.322741  0.555641  -2.380567
# 1940  AGAP008210    176.815112       -1.238195  0.267627  -4.626563
# 4112  AGAP002204     32.132459       -1.223482  0.404075  -3.027861
# ...
