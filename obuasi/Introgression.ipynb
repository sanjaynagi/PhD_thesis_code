# %%
import allel
import probe
import malariagen_data
import zarr

# %%
ag3 = malariagen_data.Ag3(pre=True)

# %%
sample_set = '1244-VO-GH-YAWSON-VMF00149'

# %% [markdown]
# It looks like the only introgression is at the VGSC. Lets also look in GAARD.

# %%
ag3.plot_aim_heatmap(aims="gamb_vs_colu", sample_sets=sample_set)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6582/355649135.py in <module>
# ----> 1 ag3.plot_aim_heatmap(aims="gamb_vs_colu", sample_sets=sample_set)
#
# ~/projects/malariagen-data-python/malariagen_data/ag3.py in plot_aim_heatmap(self, aims, sample_sets, sample_query, sort, row_height, colors, xgap, ygap)
#    4253             aims=aims,
#    4254             sample_sets=sample_sets,
# -> 4255             sample_query=sample_query,
#    4256         ).compute()
#    4257         samples = ds["sample_id"].values
#
# ~/projects/malariagen-data-python/malariagen_data/ag3.py in aim_calls(self, aims, sample_sets, sample_query)
#    4183             y = self._aim_calls_dataset(
#    4184                 aims=aims,
# -> 4185                 sample_set=s,
#    4186             )
#    4187             ly.append(y)
#
# ...

# %%
ag3.plot_aim_heatmap(aims="gambcolu_vs_arab", sample_sets=sample_set)

# %% [markdown]
# ## Introgression in GAARD

# %%
gaard_sets = ['1244-VO-GH-YAWSON-VMF00051', '1253-VO-TG-DJOGBENOU-VMF00052', '1237-VO-BJ-DJOGBENOU-VMF00050', '1245-VO-CI-CONSTANT-VMF00054']

# %%
ag3.plot_aim_heatmap(aims="gamb_vs_colu", sample_sets=gaard_sets)

# %%
ag3.plot_aim_heatmap(aims="gamb_vs_colu", sample_sets=gaard_sets)
